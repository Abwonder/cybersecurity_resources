# %% [markdown]
# ### Cybersecurity Lab on Modules

# %% [markdown]
# ### Question 1
# 1. Which os method displays the current directory?
#
# Answer here is
# getcwd()

# %%
## import library

import os

print(os.getcwd())
# Out:
# C:\Users\abioy\Documents\0. Data Science Master Course\9. Probability Distribution Density

# %% [markdown]
# ### Question 2
#
# 2. Which os method changes the current directory?
#
# chdir()

# %%
# Python3 program to change the
# directory of file using os.chdir() method

# import os library
import os

# change the current directory
# to specified directory
os.chdir(r"C:\Users\abioy\Documents")

print("Directory changed")
print()

print(os.getcwd())
# Out:
# Directory changed
#
# C:\Users\abioy\Documents

# %%
## return to normal that i am working in
import os
os.chdir(r"C:\Users\abioy\Documents\0. Data Science Master Course\9. Probability Distribution Density")
os.getcwd()
# Out:
# 'C:\\Users\\abioy\\Documents\\0. Data Science Master Course\\9. Probability Distribution Density'

# %% [markdown]
# ### Question 3
# 3. Which os method creates a directory?

# %%
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
# ...

# %%
##
import os
os.mkdir("cyber_python_Class")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 4
# 4. Which os method lists all the files and directories?
#
# Answer:
# listdir()

# %%
### 
import os
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '1.0-Probability Distribution Or Density Function.pdf',
#  '1.1- Types Of Probability Distribution.pdf',
#  '2.0-pdf,cdf,pmf.pdf',
#  '3.0-Bernoullis Distribution.pdf',
#  '4.0-Binomial Distribution.pdf',
#  '5.0-Poisson Distribution.pdf',
#  '7-Normal Or Gausssian Distribution .pdf',
#  '7.1-Q-Q Plot.ipynb',
#  'abioye.txt',
#  'cyber_python_Class',
#  'Lab on Loops.ipynb',
#  'Lab05_python.ipynb',
#  'LabModules.ipynb',
#  'README.md',
#  'Statistics Advance - 1.ipynb',
#  'users.db.txt']

# %% [markdown]
# ### ### Question 5
# 5. Which os method deletes files?

# %%
## how to delete files using os 
os.remove()

# %% [markdown]
# ### Question 6
#
# 6. Which os method deletes directories?
# os.rmdirs()

# %% [markdown]
# ### Question 7
# 7. Download the script and analyze; what is the output?
#
# Answer: False
#
# Note: os.path.exists() === > it does not see hidden files!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# I used this as an example

import os

fls = os.listdir()
print(fls)

res = os.path.exists("README.md")
print(res)
# Out:
# ['.git', '.ipynb_checkpoints', '1.0-Probability Distribution Or Density Function.pdf', '1.1- Types Of Probability Distribution.pdf', '2.0-pdf,cdf,pmf.pdf', '3.0-Bernoullis Distribution.pdf', '4.0-Binomial Distribution.pdf', '5.0-Poisson Distribution.pdf', '7-Normal Or Gausssian Distribution .pdf', '7.1-Q-Q Plot.ipynb', 'abioye.txt', 'cyber_python_Class', 'Lab on Loops.ipynb', 'Lab05_python.ipynb', 'LabModules.ipynb', 'README.md', 'Statistics Advance - 1.ipynb', 'users.db.txt']
# True

# %% [markdown]
# ### Question 8
# 8. Which os method displays the size of a file (bytes)?
# answer: path.getsize()
#
# os.path.getsize(filename)

# %%
os.path.getsize("1.0-Probability Distribution Or Density Function.pdf")
# Out:
# 1280318

# %% [markdown]
# ### Question 9
#
# 9. Download and analyze the script; what is the output?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import hashlib
m = hashlib.md5(b"a").hexdigest()
print(m)
# Out:
# 0cc175b9c0f1b6a831c399e269772661

# %% [markdown]
# ### Question 10
# 10. Change the script to use the hashlib.sha224 function; what is the output?

# %%
import hashlib
m = hashlib.sha224(b"a").hexdigest()
print(m)
# Out:
# abd37534c7d9a2efb9465de931cd7055ffdb8879563ae98078d6d6d5

# %%
# Just trying it out

import hashlib
m = hashlib.sha224(b"abioye Oyatoye").hexdigest()
print(m)
# Out:
# 0d092cf0031e0612e978c985b1b5c54d9374dff5079631c5e1e52854
