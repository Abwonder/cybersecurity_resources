# %% [markdown]
# ### Cybersecurity Python practice

# %% [markdown]
# ### Question 1
# 1. a=[3,4,1,6,9,3]; create a script that gets six numbers and prints the largest number.

# %%
a=[3,4,1,6,9,3]
highest_num = 0
for i in a:
    if i > highest_num:
        highest_num = i
    else:
        pass
print(highest_num)
# Out:
# 9

# %% [markdown]
# ### Question 2
# 2. a=[3,4,1,6,9,3]; create a script that gets six numbers, and print their sum.

# %%
a=[3,4,1,6,9,3]
sum_num = 0
for i in a:
    sum_num+=i
print(sum_num)
# Out:
# 26

# %% [markdown]
# ### Question 3
# 3. lst=['a','c','a','a','b','d','e','r','x','a']; create a script that removes duplicated items from the list.

# %%
lst=['a','c','a','a','b','d','e','r','x','a']
new_list = []
for i in lst:
    if i in new_list:
#         print("cheking")
        pass
    else:
#         print("cheking12")
        new_list.append(i)
print(new_list)
# Out:
# ['a', 'c', 'b', 'd', 'e', 'r', 'x']

# %% [markdown]
# ### Question 4
# 4. Download and analyze the script; what is the variable type of str2?
#
# ![image.png](attachment:image.png)

# %%
str = "My name is Josef, and I'm trying to write Python scripts"
str2 = str.split()
print(str2)
# Out:
# ['My', 'name', 'is', 'Josef,', 'and', "I'm", 'trying', 'to', 'write', 'Python', 'scripts']

# %%
print(type(str2))
# Out:
# <class 'list'>

# %% [markdown]
# ### The End
